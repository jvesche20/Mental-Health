# %%
# !pip install importlib
# !pip install pdfminer3k

import sys
import importlib
importlib.reload(sys)
import re

from pdfminer.pdfparser import PDFParser,PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal,LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
#from pdfminer.pdfpage import PDFPage
from pdfminer.pdfdevice import PDFDevice

from urllib.request import urlopen

from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/'My Drive'/'Peng' 

pdf_path = 'DiagnosticandstatisticalmanualofmentaldisordersDSM-5.pdf'
newname1 = 'newtest2.txt'

def extract_layout_by_page(pdf_path):
   
    laparams = LAParams() # pdfminer.layout.LAParams(line_overlap=0.5, char_margin=2.0, line_margin=0.5, word_margin=0.1, boxes_flow=0.5, detect_vertical=False, all_texts=False)

    fp = open(pdf_path, 'rb')  # 
    parser = PDFParser(fp)   # Create a PDF parser object associated with the file object. 
    document = PDFDocument(parser) # Create a PDF document object that stores the document structure.
    
    
    #Connect analyzer to document object
    parser.set_document(document)
    document.set_parser(parser)   
    
    # Check if the document allows text extraction. If not, abort 
    document.initialize()
    if not document.is_extractable:
        raise PDFTextExtractionNotAllowed
   
    rsrcmgr = PDFResourceManager()  # Create a PDF resource manager object that stores shared resources
   
    #device = PDFDevice(rsrcmgr) #'PDFDevice' object has no attribute 'get_result'
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)  # Create a PDF page aggregator object
    interpreter = PDFPageInterpreter(rsrcmgr, device) # Create a PDF interpreter object

    layouts = []
    count = 0
    
    # Process each page contained in the document 
    for page in document.get_pages():
        #if count < 100:
            interpreter.process_page(page)
            layouts.append(device.get_result()) 
            count = count + 1
        #else:
            #break
    return layouts

def pdf_to_txt(pdf_path, newname1):
    page_layouts = extract_layout_by_page(pdf_path)
    with open(newname1, 'w', encoding='utf-8') as f:
        for current_page in page_layouts:
            # Get text
            for x in current_page:
                if hasattr(x, "get_text"):
                    # result.append(x.get_text())
                    results = x.get_text()
                    # print(type(results))
                    if results == ' \n':
                        continue
                    # results=list(results)
                    # with open(newname1, 'a', encoding='utf-8') as f:
                    f.write(results)
                    # f.close()

    
    with open(newname1, 'r', encoding='UTF-8-sig') as f:
        content = f.readlines()
        print(content)
    pattern = re.compile(r'\s{1,2}\n')
    newcontent = []
    for i in content:
        if bool(re.search(pattern, i)) is False:
            j = i.replace('\n', '').replace(' \n', '')
            newcontent.append(j)
        else:
            newcontent.append(i)
    f.close()
    print(newcontent)
    with open(newname1, 'w', encoding='UTF-8') as f:
        for i in newcontent:
            f.write(i)
    f.close()
    return newname1

pdf_to_txt(pdf_path, newname1)
# Out:
# Requirement already satisfied: importlib in /usr/local/lib/python3.6/dist-packages (1.0.4)
# Requirement already satisfied: pdfminer3k in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: pytest>=2.0 in /usr/local/lib/python3.6/dist-packages (from pdfminer3k) (3.6.4)
# Requirement already satisfied: ply>=3.4 in /usr/local/lib/python3.6/dist-packages (from pdfminer3k) (3.11)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (42.0.2)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (8.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (1.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (1.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (19.3.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest>=2.0->pdfminer3k) (0.7.1)
# WARNING:root:Literal required: 'The process that creates this PDF constitutes a trade secret of codeMantra, LLC and is protected by the copyright laws of the United States'
# WARNING:root:Literal required: '3-Heights(TM) PDF Producer 4.2.26.0 (http://www.pdf-tools.com)'
# WARNING:root:Literal required: 'Quite Imposing 1.5d (EN)'
# WARNING:root:Literal required: 'American Psychiatric Association'
# WARNING:root:Literal required: LLC
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Peng
# WARNING:pdfminer.layout:Too many boxes (134) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (102) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (113) to group, skipping.
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 49
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 29
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 36
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 29
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 91
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 29
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+Wingdings-Regular', cidcoding='Adobe-Identity'>, 137
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 48
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+Wingdings-Regular', cidcoding='Adobe-Identity'>, 137
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 39
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AADSYP+TimesNewRoman,Bold', cidcoding='Adobe-Identity'>, 29
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 66
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+TimesNewRoman,Italic', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+TimesNewRoman,Italic', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+TimesNewRoman,Italic', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.layout:Too many boxes (114) to group, skipping.
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+TimesNewRoman,Italic', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+TimesNewRoman,Italic', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+TimesNewRoman,Italic', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+Calibri,Bold', cidcoding='Adobe-Identity'>, 886
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+Calibri,Bold', cidcoding='Adobe-Identity'>, 886
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='AAAAAD+Calibri', cidcoding='Adobe-Identity'>, 884
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 139
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 93
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 15
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 21
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 19
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 20
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 21
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 36
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 89
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 48
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 69
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 92
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 29
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 73
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 39
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 69
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 92
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 36
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 11
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 39
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 36
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 21
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 19
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 12
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 15
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 93
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 15
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 21
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 19
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 20
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 19
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 15
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 42
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 89
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 55
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 93
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 69
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 83
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 73
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 83
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 73
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# ...
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 69
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 92
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 73
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 90
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 90
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 83
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 68
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 36
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 92
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 15
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 74
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 70
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 15
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 84
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 88
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 90
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 83
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 72
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 76
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 81
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 73
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 85
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 82
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 80
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='BBNXUE+TimesNewRoman', cidcoding='Adobe-Identity'>, 3
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 'newtest2.txt'
